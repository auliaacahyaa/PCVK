# %% [markdown]
# <a href="https://colab.research.google.com/github/auliaacahyaa/PCVK/blob/main/Week1_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kelompok 4 :**
#
# 1. Afdhol Affanuddin (2141720253)
# 2. Andhito Galih Nur Cahyo (2141720138)
# 3. Aulia Cahya Briliana (2141720092)

# %%
Nama : Aulia Cahya Briliana

Nomor : 09

NIM : 2141720092

Kelas : TI-3D

# %% [markdown]
# **SOAL**
#
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:
#
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan. Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2

# %% [markdown]
# **JAWAB :**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
img_4 = cv.imread('/content/foto ktp 2.jpg')
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB)
cv2_imshow(img_4)
plt.imshow(img_5)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x1045>

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
#
# Ketika kita membaca gambar menggunakan OpenCV dan ingin menampilkannya dengan Matplotlib, kita perlu mengonversi dari format BGR (OpenCV) ke format RGB (Matplotlib). Karena Matplotlib hanya membaca format RGB. Jika kita tidak mengonversi, warna gambar mungkin akan terlihat aneh atau terbalik.

# %% [markdown]
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut.
#
# Kelompok 1 tutup bagian nomor NIK dan nama.
#
# Kelompok 2 tutup bagian TTL dan Jenis Kelamin.
#
# Kelompok 3 tutup bagian Gol. Darah dan TTD.
#
# **Kelompok 4 tutup bagian Alamat dan Kecamatan**.
#
# Kelompok 5 tutup bagian Agama dan Status Kawin.
#
# Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
#
# Kelompok 7 tutup bagian berlaku hingga dan foto.
#
# Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto.
#
# Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP.
#
# Kelompok 10 tutup bagian RT/RW dan Kel/desa.
#
# **Tutup menggunakan 2 kotak warna yang berbeda.**
#
# Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2

# %%
img_4s = np.copy(img_4)
#tutup bagian alamat
for y in range (410,1000):
  for x in range (380,420):
    img_4s[x,y] = [0,0,255]

#tutup bagian kecamatan
img_4ss = np.copy(img_4s)
for y in range (410,700):
  for x in range (520,550):
    img_4ss[x,y] = [255,0,143]
final_frame = cv.hconcat((img_4, img_4ss))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=3000x1045>
